# %%
import requests
from bs4 import BeautifulSoup

# %%
url_month = 'https://letterboxd.com/films/ajax/popular/this/month/size/small/'
top_month = requests.get(url_month)

# %%
soup_month = BeautifulSoup(top_month.content,'html.parser')
soup_month
# Out:
# <section class="ui-block-header filtered-message body-text -small message-text">
# <h2 class="ui-block-heading">
# 			There are 536,979 films.
# 		</h2>
# </section>
# <ul class="poster-list -p70 -grid">
# <li class="listitem poster-container">
# ...

# %%
films_month = [soup_month.find_all(title=True)[i]['title']\
               for i in range(len(soup_month.find_all(title=True)))]
films_month
# Out:
# ['Palm Springs (2020)',
#  'Parasite (2019)',
#  'Knives Out (2019)',
#  'The Kissing Booth 2 (2020)',
#  'Host (2020)',
#  'Inception (2010)',
#  'The Old Guard (2020)',
#  'Joker (2019)',
#  'Jojo Rabbit (2019)',
#  'An American Pickle (2020)',
#  'Midsommar (2019)',
#  'Eternal Sunshine of the Spotless Mind (2004)',
#  'Portrait of a Lady on Fire (2019)',
#  'Pulp Fiction (1994)',
#  'Once Upon a Time… in Hollywood (2019)',
#  'Fight Club (1999)',
#  'Interstellar (2014)',
#  'The Truman Show (1998)',
#  'The Dark Knight (2008)',
#  'Lady Bird (2017)',
#  'Spirited Away (2001)',
#  'Scott Pilgrim vs. the World (2010)',
#  'The Lighthouse (2019)',
#  'The Rental (2020)',
#  'Get Out (2017)',
#  'La La Land (2016)',
#  'Hamilton (2020)',
#  'The Shining (1980)',
#  'Uncut Gems (2019)',
#  'The Grand Budapest Hotel (2014)',
#  'Little Women (2019)',
#  'Spider-Man: Into the Spider-Verse (2018)',
#  'She Dies Tomorrow (2020)',
#  'The Wolf of Wall Street (2013)',
# ...

# %%
films_month[0][-5:-1]
# Out:
# '2020'

# %%
url_month = 'https://letterboxd.com/films/ajax/popular/this/month/size/small/'
top_month = requests.get(url_month)
soup_month = BeautifulSoup(top_month.content,'html.parser')
films_month = [soup_month.find_all(title=True)[i]['title']\
               for i in range(len(soup_month.find_all(title=True)))]

# %%
soup_month.find_all(title=True)[0]['href']
# Out:
# '/film/palm-springs-2020/'
