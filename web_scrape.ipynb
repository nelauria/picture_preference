# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def top():
    time_period = 'this/month'
    url = 'https://letterboxd.com/films/ajax/popular/'+time_period+'/size/small/'
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    films_divs = soup.find_all(title=True)
    films = pd.DataFrame()
    films['Title'] = [films_divs[i]['title'][:-7] for i in range(len(films_divs))]
    films['Year'] = [films_divs[i]['title'][-5:-1] for i in range(len(films_divs))]
    films['href'] = [films_divs[i]['href'] for i in range(len(films_divs))]
    return films

# %%
top()
# Out:
#                        Title  Year                             href
# 0               Palm Springs  2020         /film/palm-springs-2020/
# 1                   Parasite  2019             /film/parasite-2019/
# 2        The Kissing Booth 2  2020       /film/the-kissing-booth-2/
# 3                 Knives Out  2019           /film/knives-out-2019/
# 4                       Host  2020                 /film/host-2020/
# ..                       ...   ...                              ...
# 67       Lost in Translation  2003       /film/lost-in-translation/
# 68              Nightcrawler  2014              /film/nightcrawler/
# 69                    Zodiac  2007                    /film/zodiac/
# 70  The Shawshank Redemption  1994  /film/the-shawshank-redemption/
# 71    Avengers: Infinity War  2018     /film/avengers-infinity-war/
#
# [72 rows x 3 columns]

# %%
main = 'https://letterboxd.com'
ind = 0
film = films.iloc[ind]
film_url = main+film.href
film_page = requests.get(film_url)
film_soup = BeautifulSoup(film_page.content,'html.parser')
genre_links = film_soup.find(id='tab-genres').find_all('a')
films.loc[ind,'Genres'] = [genre_links[i].string for i in range(len(genre_links))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-3969ab0e5f37> in <module>
#       6 film_soup = BeautifulSoup(film_page.content,'html.parser')
#       7 genre_links = film_soup.find(id='tab-genres').find_all('a')
# ----> 8 films.loc[ind,'Genres'] = [genre_links[i].string for i in range(len(genre_links))]
#
# c:\users\nolan\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# c:\users\nolan\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1599                             indexer, self.obj.axes
#    1600                         )
# -> 1601                         self._setitem_with_indexer(new_indexer, value)
#    1602
#    1603                         return
#
# c:\users\nolan\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1664                 if is_list_like_indexer(value) and 0 != lplane_indexer != len(value):
#    1665                     # Exclude zero-len for e.g. boolean masking that is all-false
# -> 1666                     raise ValueError(
#    1667                         "cannot set using a multi-index "
#    1668                         "selection indexer with a different "
#
# ValueError: cannot set using a multi-index selection indexer with a different length than the value

# %%
film_soup.body
# Out:
# <body class="film backdropped" data-tmdb-id="587792" data-tmdb-type="movie" data-type="film">
# <div class="backdrop-container"> <div class="backdrop-wrapper" data-backdrop="https://a.ltrbxd.com/resized/sm/upload/xz/2a/8y/83/palm-springs-1200-1200-675-675-crop-000000.jpg?k=f3292a5b45" data-backdrop2x="https://a.ltrbxd.com/resized/sm/upload/xz/2a/8y/83/palm-springs-1920-1920-1080-1080-crop-000000.jpg?k=7898ef44e6" data-backdropmobile="https://a.ltrbxd.com/resized/sm/upload/xz/2a/8y/83/palm-springs-960-960-540-540-crop-000000.jpg?k=7898ef44e6" data-offset="112" id="backdrop"> <div class="backdropplaceholder js-backdrop-placeholder" style="background-image: url(https://a.ltrbxd.com/resized/sm/upload/xz/2a/8y/83/palm-springs-48-48-27-27-crop.png?k=b6da1ad232); background-position: center -112px;"></div> <div class="backdropimage js-backdrop-image" style="background-position: center -112px;"></div> <div class="backdropmask js-backdrop-fade"></div> </div> </div>
# <script>
# 	var filmData = { id: 515467, name: "Palm Springs", releaseYear: "2020", posterURL: "/film/palm-springs-2020/image-150/", path: "/film/palm-springs-2020/" };
#
#
#
# </script>
# <script>
# var mainMenu = [];
#
#
# 	mainMenu.push({
# 		"id": 1,
# 		"url": "/sign-in/",
# 		"name": "Sign In",
# 		"cssClassCode": "sign-in-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": true,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 2,
# 		"url": "/create-account/",
# 		"name": "Create Account",
# 		"cssClassCode": "create-account-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 3,
# 		"url": "/",
# 		"name": "Home",
# 		"cssClassCode": "person-home",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 4,
# 		"url": "/activity/",
# 		"name": "Activity",
# 		"cssClassCode": "main-nav-activity",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 5,
# 		"url": "/films/",
# 		"name": "Films",
# 		"cssClassCode": "films-page main-nav-films",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 6,
# 		"url": "/lists/",
# 		"name": "Lists",
# 		"cssClassCode": "lists-page main-nav-lists",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 7,
# 		"url": "/people/",
# 		"name": "People",
# 		"cssClassCode": "main-nav-people",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 8,
# 		"url": "/search/",
# 		"name": "Search results",
# 		"cssClassCode": "",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"selected": false
# 	});
#
# </script>
# <header class="site-header js-hide-in-app" id="header">
# <div class="site-header-bg"></div>
# <section>
# <h1 class="site-logo"><a class="logo replace" href="/">Letterboxd — Your life in film</a></h1>
# <div class="react-component" data-component-class="globals.comps.NavComponent"></div>
# <form action="#" autocapitalize="off" autocorrect="off" class="signin signin-form js-header-signin-form js-signin" data-url="/user/login.do" id="signin" method="post" novalidate="novalidate">
# <input name="__csrf" type="hidden" value="placeholder"/>
# <fieldset class="fieldset">
# <div class="fields">
# <div class="col">
# <label for="username">Username or Email</label>
# <input autocomplete="email" class="field signin-field" data-focus-control="signingIn" id="username" name="username" tabindex="1" type="email" value=""/>
# </div>
# <div class="col">
# <label for="password">Password</label>
# <input autocomplete="current-password" class="field signin-field" id="password" name="password" tabindex="2" type="password" value=""/>
# </div>
# <div class="signin-actions">
# <label class="option-label -checkbox -small" for="remember">
# <input class="checkbox" id="remember" name="remember" tabindex="3" type="checkbox" value="true"/><i class="substitute"></i>
# <span class="focus">Remember<span class="mob-hide"> me</span></span>
# </label>
# <p class="reset" tabindex="5"><a class="reset-password-link" href="/user/request-password-reset" target="_top">Forgotten<span class="elongated"> password</span>?</a></p>
# </div>
# <div class="col buttons">
# <div class="button-container"><input class="button -action button-green" tabindex="4" type="submit" value="Sign in"/><i></i></div>
# <div class="close js-close-signin">×</div>
# </div>
# </div>
# </fieldset>
# <div class="errormessage" id="signin-message"></div>
# </form>
# <form action="/search/" class="js-search-form search-form" id="search" method="get">
# <fieldset>
# <label class="hidden" for="search-q">Search:</label>
# <input class="field -borderless" data-lpignore="true" id="search-q" name="q" type="text" value=""/>
# <input class="action" type="submit" value="Search"/>
# </fieldset>
# </form>
# </section>
# </header>
# <div class="site-body -backdrop" id="content">
# <div class="content-wrap">
# <div class="cols-3 overflow" id="film-page-wrapper">
# <div class="col-6 gutter-right-1 col-poster-large" id="js-poster-col">
# <section class="poster-list -p230 no-hover el col">
# <div class="react-component film-poster film-poster-515467 poster" data-add-to-watchlist-action="/film/palm-springs-2020/add-to-watchlist/" data-component-class="globals.comps.FilmPosterComponent" data-film-id="515467" data-film-link="/film/palm-springs-2020/" data-film-name="Palm Springs" data-film-release-year="2020" data-hide-tooltip="true" data-mark-as-not-watched-action="/film/palm-springs-2020/mark-as-not-watched/" data-mark-as-watched-action="/film/palm-springs-2020/mark-as-watched/" data-new-list-with-film-action="/list/new/with/palm-springs-2020/" data-poster-url="/film/palm-springs-2020/image-150/" data-rate-action="/film/palm-springs-2020/rate/" data-remove-from-watchlist-action="/film/palm-springs-2020/remove-from-watchlist/" data-show-menu="true" data-target-link="/film/palm-springs-2020/" data-target-link-target=""> <img alt="Palm Springs" class="image" height="345" itemprop="image" src="https://a.ltrbxd.com/resized/film-poster/5/1/5/4/6/7/515467-palm-springs-0-230-0-345-crop.jpg?k=ebe330876d" srcset="https://a.ltrbxd.com/resized/film-poster/5/1/5/4/6/7/515467-palm-springs-0-460-0-690-crop.jpg?k=89c19ec462 2x" width="230"/> <img alt="Palm Springs" class="image -empty-poster-image hidden" height="345" src="https://s.ltrbxd.com/static/img/empty-poster-230.8b0c4ca0.png" width="230"/> <span class="frame" title="Palm Springs (2020)"> <span class="frame-title">Palm Springs</span> </span> </div> <div class="js-serial-csi" data-on-load="" data-src="/esi/film/palm-springs-2020/stats/"> <ul class="film-stats"> <li class="stat"><a class="has-icon icon-placeholder"> </a></li> </ul> </div>
# </section>
# <div class="js-csi" data-on-load="csi-availability" data-src="/csi/film/palm-springs-2020/availability/?esiAllowUser=true">
# <section class="watch-panel">
# <div class="header">
# <h3 class="title">Where to watch</h3>
# <p class="trailer-link js-watch-panel-trailer">
# <a class="play track-event js-trailer-zoom" data-track-category="Trailer" href="//www.youtube.com/embed/CpBLtXduh_k?rel=0&amp;wmode=transparent">
# <span class="name">Trailer</span>
# </a>
# </p>
# </div>
# <div id="watch">
# <div class="other">
# <span class="more"> </span>
# <a class="jw-branding" href="https://www.justwatch.com" target="_blank">JustWatch</a>
# </div>
# </div>
# </section>
# </div>
# <script id="script-451ef1d5-9d87-4178-8187-3c94707055b8">
# 	(function() {
# 		if (person.showAds) {
# 			var code = renderMobile ? 2 : 1;
# 			var modalContent = "<article><h1>Upgrade to remove ads</h1><p class='body-text -hero'>Letterboxd is an independent service created by a small team, and we rely mostly on the support of our members to maintain our site and apps. Please consider upgrading to a <a href='" + baseURL + "/pro/'>Pro account</a>—for less than a couple bucks a month, you’ll get cool additional features like all-time and annual stats pages (<a href='https://letterboxd.com/jack/stats/'><u>example</u></a>), the ability to select (and filter by) your favorite streaming services, and no ads!</p><a href='" + baseURL + "/pro/' class='flat-button -action -uppercase button-action'>Tell me about Pro</a></article>";
#
# 					var $div = $("<div />").attr("id", "div-gpt-ad-1529350096921-" + code).addClass("alig-div -sidebar");
#
# 			var $modal = $("<div />").attr("id", "alig-modal-451ef1d5-9d87-4178-8187-3c94707055b8").addClass("modal signup-modal").html(modalContent);
# 			var $a = $("<a />").attr("href", "#alig-modal-451ef1d5-9d87-4178-8187-3c94707055b8").addClass("alig-hide -sidebar js-hide-in-app").html("Remove Ads <span>&times;</span>");
# 			var $modalContainer = $("<div />").css("display", "none").html($modal);
# 			$("#script-451ef1d5-9d87-4178-8187-3c94707055b8").after($div);
# 			if (typeof googletag !== "undefined") {
# 				googletag.cmd.push(function() {googletag.display("div-gpt-ad-1529350096921-" + code);});
# 			}
# 			$div.after($a).after($modalContainer);
# 			$a.on("click", function(e) { e.preventDefault(); if (renderMobile) $(window).scrollTo(0); $(this).colorbox({inline: true, width: renderMobile ? "90%" : 520}); });
# 		}
# 	})();
# </script>
# </div>
# <div class="col-17">
# <section id="featured-film-header">
# <h1 class="headline-1 js-widont prettify">Palm Springs</h1>
# <p>
# <small class="number"><a href="/films/year/2020/">2020</a></small>
#
#
#
#
# 					Directed by <a href="/director/max-barbakow/"><span class="prettify">Max Barbakow</span></a>
# </p>
# </section>
# <section class="section col-10 col-main">
# <section>
# <div class="review body-text -prose -hero prettify">
# <h3 class="hidden">Synopsis</h3>
# <div class="truncate" data-truncate="450">
# <p>When carefree Nyles and reluctant maid of honor Sarah have a chance encounter at a Palm Springs wedding, things get complicated as they are unable to escape the venue, themselves, or each other.</p>
# </div>
# </div>
# <script id="script-4bb8608a-f705-40d6-b258-1b37a7897bf8">
# 	(function() {
# 		if (person.showAds) {
# 			var code = renderMobile ? 2 : 1;
# 			var modalContent = "<article><h1>Upgrade to remove ads</h1><p class='body-text -hero'>Letterboxd is an independent service created by a small team, and we rely mostly on the support of our members to maintain our site and apps. Please consider upgrading to a <a href='" + baseURL + "/pro/'>Pro account</a>—for less than a couple bucks a month, you’ll get cool additional features like all-time and annual stats pages (<a href='https://letterboxd.com/jack/stats/'><u>example</u></a>), the ability to select (and filter by) your favorite streaming services, and no ads!</p><a href='" + baseURL + "/pro/' class='flat-button -action -uppercase button-action'>Tell me about Pro</a></article>";
#
# 					var $div = $("<div />").attr("id", "Letterboxd-MPU-FILM").addClass("AdvallyTag alig-div -tile300x250 -alignleft").attr("data-slot", "/1093718/LETTERBOXD/Letterboxd-MPU-FILM").attr("data-size", "300x250");
#
# 			var $modal = $("<div />").attr("id", "alig-modal-4bb8608a-f705-40d6-b258-1b37a7897bf8").addClass("modal signup-modal").html(modalContent);
# 			var $a = $("<a />").attr("href", "#alig-modal-4bb8608a-f705-40d6-b258-1b37a7897bf8").addClass("alig-hide -alignleft -sidebar js-hide-in-app").html("Remove Ads <span>&times;</span>");
# 			var $modalContainer = $("<div />").css("display", "none").html($modal);
# 			$("#script-4bb8608a-f705-40d6-b258-1b37a7897bf8").after($div);
# 			if (typeof googletag !== "undefined") {
# 				googletag.cmd.push(function() {googletag.display("div-gpt-ad-1529350096921-" + code);});
# 			}
# 			$div.after($a).after($modalContainer);
# 			$a.on("click", function(e) { e.preventDefault(); if (renderMobile) $(window).scrollTo(0); $(this).colorbox({inline: true, width: renderMobile ? "90%" : 520}); });
# 		}
# 	})();
# </script>
# </section>
# <div data-selected-tab="" id="tabbed-content">
# <header>
# <ul>
# <li><a data-id="cast" href="/film/palm-springs-2020/">Cast</a></li>
# <li><a data-id="crew" href="/film/palm-springs-2020/crew/" id="crew">Crew</a></li>
# <li><a data-id="details" href="/film/palm-springs-2020/details/">Details</a></li>
# <li><a data-id="genres" href="/film/palm-springs-2020/genres/">Genres</a></li>
# </ul>
# </header>
# <div class="tabbed-content-block" id="tab-cast">
# <h3 class="hidden">Cast</h3>
# <div class="cast-list text-sluglist">
# <p>
# <a class="text-slug tooltip" href="/actor/andy-samberg/" title="Nyles">Andy Samberg</a> <a class="text-slug tooltip" href="/actor/cristin-milioti/" title="Sarah">Cristin Milioti</a> <a class="text-slug tooltip" href="/actor/jk-simmons/" title="Roy">J.K. Simmons</a> <a class="text-slug tooltip" href="/actor/peter-gallagher/" title="Howard">Peter Gallagher</a> <a class="text-slug tooltip" href="/actor/meredith-hagner/" title="Misty">Meredith Hagner</a> <a class="text-slug tooltip" href="/actor/camila-mendes/" title="Tala">Camila Mendes</a> <a class="text-slug tooltip" href="/actor/tyler-hoechlin/" title="Abe">Tyler Hoechlin</a> <a class="text-slug tooltip" href="/actor/chris-pang/" title="Trevor">Chris Pang</a> <a class="text-slug tooltip" href="/actor/jacqueline-obradors/" title="Pia">Jacqueline Obradors</a> <a class="text-slug tooltip" href="/actor/june-squibb/" title="Nana Schlieffen">June Squibb</a> <a class="text-slug tooltip" href="/actor/tongayi-chirisa/" title="Jerry">Tongayi Chirisa</a> <a class="text-slug tooltip" href="/actor/dale-dickey/" title="Darla">Dale Dickey</a> <a class="text-slug tooltip" href="/actor/conner-omalley/" title="Randy">Conner O'Malley</a> <a class="text-slug tooltip" href="/actor/jena-friedman/" title="Daisy the Bartender">Jena Friedman</a> <a class="text-slug tooltip" href="/actor/brian-duffy/" title="Spuds">Brian Duffy</a> <a class="text-slug tooltip" href="/actor/martin-kildare/" title="Ted the Bartender">Martin Kildare</a> <a class="text-slug tooltip" href="/actor/lilli-birdsell/" title="Jamie">Lilli Birdsell</a> <a class="text-slug tooltip" href="/actor/ryan-sturtz/" title="Cop">Ryan Sturtz</a> <a class="text-slug tooltip" href="/actor/clifford-v-johnson-1/" title="Professor">Clifford V. Johnson</a> <a class="text-slug tooltip" href="/actor/calki-garcia/" title="DJ Nice Height">Calki Garcia</a> <a class="text-slug tooltip" href="/actor/isla-sellers/" title="Roy's Daughter">Isla Sellers</a> <a class="text-slug tooltip" href="/actor/matt-smith-19/" title="Out of Town Dad">Matt Smith</a> <a class="text-slug tooltip" href="/actor/rebecca-smith-2/" title="Out of Town Mom">Rebecca Smith</a> <a class="text-slug tooltip" href="/actor/jake-smith-3/" title="Out of Town Older Son">Jake Smith</a> <a class="text-slug tooltip" href="/actor/noah-smith-4/" title="Out of Town Younger Son">Noah Smith</a> <a class="text-slug tooltip" href="/actor/rocky-bonifield/" title="Wedding Guest (uncredited)">Rocky Bonifield</a> <a class="text-slug tooltip" href="/actor/erin-flannery-1/" title="Wedding Guest (uncredited)">Erin Flannery</a> <a class="text-slug tooltip" href="/actor/david-hutchison/" title="Biker (uncredited)">David Hutchison</a> <a class="text-slug tooltip" href="/actor/mark-kubr/" title="Biker (uncredited)">Mark Kubr</a>
# <a class="text-slug" id="show-cast-overflow">Show All…</a>
# <span id="cast-overflow" style="display:none;">
# <a class="text-slug tooltip" href="/actor/david-philip-reed/" title="Truck Driver (uncredited)">David Philip Reed</a>
# </span>
# </p>
# </div>
# </div>
# <div class="tabbed-content-block column-block" id="tab-crew">
# <h3><span>Director</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/director/max-barbakow/">Max Barbakow</a>
# </p>
# </div>
# <h3><span>Producers</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/producer/akiva-schaffer/">Akiva Schaffer</a> <a class="text-slug" href="/producer/andy-samberg/">Andy Samberg</a> <a class="text-slug" href="/producer/jorma-taccone/">Jorma Taccone</a> <a class="text-slug" href="/producer/dylan-sellers/">Dylan Sellers</a> <a class="text-slug" href="/producer/becky-sloviter/">Becky Sloviter</a> <a class="text-slug" href="/producer/gabriela-revilla-lugo/">Gabriela Revilla Lugo</a> <a class="text-slug" href="/producer/alex-dong/">Alex Dong</a>
# </p>
# </div>
# <h3><span>Writer</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/writer/andy-siara/">Andy Siara</a>
# </p>
# </div>
# <h3><span>Editors</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/editor/andrew-dickler/">Andrew Dickler</a> <a class="text-slug" href="/editor/matt-friedman/">Matt Friedman</a>
# </p>
# </div>
# <h3><span>Cinematography</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/cinematography/quyen-tran/">Quyen Tran</a>
# </p>
# </div>
# <h3><span>Production Design</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/production-design/jason-kisvarday/">Jason Kisvarday</a>
# </p>
# </div>
# <h3><span>Art Direction</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/art-direction/tim-ford/">Tim Ford</a>
# </p>
# </div>
# <h3><span>Set Decoration</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/set-decoration/kelsi-ephraim/">Kelsi Ephraim</a>
# </p>
# </div>
# <h3><span>Composer</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/composer/matthew-compton/">Matthew Compton</a>
# </p>
# </div>
# <h3><span>Sound</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/sound/jason-gaya/">Jason Gaya</a> <a class="text-slug" href="/sound/robert-chen-1/">Robert Chen</a> <a class="text-slug" href="/sound/jon-wakeham/">Jon Wakeham</a>
# </p>
# </div>
# <h3><span>Costumes</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/costumes/colin-wilkes/">Colin Wilkes</a>
# </p>
# </div>
# </div>
# <div class="tabbed-content-block column-block" id="tab-details">
# <h3><span>Studios</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/studio/limelight-2/">Limelight</a> <a class="text-slug" href="/studio/party-over-here/">Party Over Here</a> <a class="text-slug" href="/studio/neon-1/">Neon</a> <a class="text-slug" href="/studio/the-lonely-island-1/">The Lonely Island</a> <a class="text-slug" href="/studio/culmination-productions/">Culmination Productions</a>
# </p>
# </div>
# <h3><span>Country</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/films/country/usa/">USA</a>
# </p>
# </div>
# <h3><span>Language</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/films/language/english/">English</a>
# </p>
# </div>
# <h3><span>Alternative Titles</span></h3>
# <div class="text-indentedlist">
# <p>
# 										Зависнуть в Палм-Спрингс, Палм-Спрінгз, Палм-Спрінґз
# 									</p>
# </div>
# </div>
# <div class="tabbed-content-block" id="tab-genres">
# <h3 class="hidden">Genres</h3>
# <div class="text-sluglist capitalize">
# <p>
# <a class="text-slug" href="/films/genre/mystery/">mystery</a> <a class="text-slug" href="/films/genre/fantasy/">fantasy</a> <a class="text-slug" href="/films/genre/romance/">romance</a> <a class="text-slug" href="/films/genre/comedy/">comedy</a>
# </p>
# </div>
# </div>
# </div>
# <p class="text-link text-footer">
# 				90 mins
#
# 					More details at
# 					<a class="micro-button track-event" data-track-action="IMDb" href="http://www.imdb.com/title/tt9484998/maindetails">IMDb</a>
# <a class="micro-button track-event" data-track-action="TMDb" href="https://www.themoviedb.org/movie/587792/">TMDb</a>
# <span class="report-link has-icon icon-report hide-when-logged-out tooltip tooltip-close-on-click" data-report-url="/ajax/film:515467/report-form" title="Report this film">Report this film</span>
# </p>
# </section>
# <aside class="sidebar">
# <section class="actions-panel" id="userpanel">
# <ul class="js-actions-panel">
# <li class="js-csi" data-on-load="" data-src="/csi/film/palm-springs-2020/sidebar-user-actions/?esiAllowUser=true">
# </li>
# <li class="panel-share">
# <div id="share-off"><a href="#">Share</a></div>
# <div id="share-on" style="display:none;">
# <input class="field -transparent" readonly="" type="text" value="https://boxd.it/lCXQ"/>
# <a class="replace popup-link tw-popup" href="https://twitter.com/intent/tweet?text=Palm%20Springs%20%282020%29%20on%20%40letterboxd%3A%20https%3A%2F%2Fboxd.it%2FlCXQ" title="Tweet a link">Tweet</a>
# <a class="replace popup-link fb-popup" href="https://www.facebook.com/dialog/feed?app_id=173683136069040&amp;link=https%3A%2F%2Fletterboxd.com%2Ffilm%2Fpalm-springs-2020%2F&amp;picture=https%3A%2F%2Fa.ltrbxd.com%2Fresized%2Ffilm-poster%2F5%2F1%2F5%2F4%2F6%2F7%2F515467-palm-springs-0-230-0-345-crop.jpg%3Fk%3Debe330876d&amp;name=Palm%20Springs%20%282020%29%20on%20Letterboxd.com&amp;caption=Directed%20by%20Max%20Barbakow&amp;description=When%20carefree%20Nyles%20and%20reluctant%20maid%20of%20honor%20Sarah%20have%20a%20chance%20encounter%20at%20a%20Palm%20Springs%20wedding%2C%20things%20get%20complicated%20as%20they%20are%20unable%20to%20escape%20the%20venue%2C%20themselves%2C%20or%20each%20other.&amp;message=&amp;display=popup&amp;redirect_uri=https://letterboxd.com/facebook-share" title="Share to Facebook">Share</a>
class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="51822" data-film-slug="/film/the-cabinet-of-dr-caligari-1920/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/the-cabinet-of-dr-caligari-1920/" data-target-link-target=""> <img alt="The Cabinet of Dr. Caligari" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="49986" data-film-slug="/film/the-golem-how-he-came-into-the-world/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/the-golem-how-he-came-into-the-world/" data-target-link-target=""> <img alt="The Golem: How He Came Into the World" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="8100" data-film-slug="/film/the-phantom-carriage/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/the-phantom-carriage/" data-target-link-target=""> <img alt="The Phantom Carriage" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="51471" data-film-slug="/film/nosferatu/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/nosferatu/" data-target-link-target=""> <img alt="Nosferatu" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> </ul> <span class="overlay"></span> </a> <div class="film-list-summary"> <h2 class="title-2 prettify"> <a href="/torrentfantasma/list/acervo-fantasma/">ACERVO FANTASMA</a> </h2> <div class="attribution-block"> <a class="avatar -a16" href="/torrentfantasma/"> <img alt="T0rr3nt Fantasma" height="16" src="https://a.ltrbxd.com/resized/avatar/twitter/2/5/0/3/3/5/6/shard/blob-0-32-0-32-crop.png?k=e65680cef3" width="16"/> </a> <p class="attribution"> <strong class="name"><a href="/torrentfantasma/">T0rr3nt Fantasma</a></strong> <small class="value">811 films</small> <span class="content-metadata"> <a class="has-icon icon-16 icon-like" href="/torrentfantasma/list/acervo-fantasma/likes/">130</a> <a class="has-icon icon-16 icon-comment" href="/torrentfantasma/list/acervo-fantasma/#comments"> 1 </a> <a class="has-icon icon-16 icon-edit show-for-owner" data-owner="torrentfantasma" href="/torrentfantasma/list/acervo-fantasma/edit/" rel="nofollow">Edit</a> </span> </p> </div> <div class="body-text -prose" data-more="/torrentfantasma/list/acervo-fantasma/"> <p>twitter.com/torrentfantasma</p><p>LISTA COM TODOS FILMES DISPONIVEL NO D_RIVE (LISTA ATUALIZADA CONSTANTEMENTE)</p><p>LINK DO DRIVE (TIRAR OS ESPAÇOS) https:// drive.google.com/ drive/u/1/folders/1xKaWJhjoqsVTN ...
# <section class="list -overlapped -summary" data-film-list-id="588160" data-person="TajLV"><a class="list-link" href="/tajlv/list/condemned-films-rated-morally-offensive-by-1/"> <ul class="poster-list -p70 -overlapped"> <li class="poster film-poster really-lazy-load listitem" data-film-id="86802" data-film-slug="/film/21-over/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/21-over/" data-target-link-target=""> <img alt="21 &amp; Over" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70
class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="46763" data-film-slug="/film/forgetting-sarah-marshall/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/forgetting-sarah-marshall/" data-target-link-target=""> <img alt="Forgetting Sarah Marshall" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="47867" data-film-slug="/film/napoleon-dynamite/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/napoleon-dynamite/" data-target-link-target=""> <img alt="Napoleon Dynamite" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="41276" data-film-slug="/film/17-again/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/17-again/" data-target-link-target=""> <img alt="17 Again" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> <li class="poster film-poster really-lazy-load listitem" data-film-id="50518" data-film-slug="/film/the-breakfast-club/" data-image-height="105" data-image-width="70" data-linked="unlinked" data-menu="no-menu" data-target-link="/film/the-breakfast-club/" data-target-link-target=""> <img alt="The Breakfast Club" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.b35adaab.png" width="70"/><span class="frame"><span class="frame-title"></span></span> </li> </ul> <span class="overlay"></span> </a> <div class="film-list-summary"> <h2 class="title-2 prettify"> <a href="/undyingcheese/list/movies-that-make-me-feel-nice/">Movies that make me feel nice</a> </h2> <div class="attribution-block"> <a class="avatar -a16" href="/undyingcheese/"> <img alt="Blake" height="16" src="https://secure.gravatar.com/avatar/9e4bd6230ca5954dfcb75693b7a783e9?rating=PG&amp;size=32&amp;border=&amp;default=https%3A%2F%2Fs.ltrbxd.com%2Fstatic%2Fimg%2Favatar32.728df495.png" width="16"/> </a> <p class="attribution"> <strong class="name"><a href="/undyingcheese/">Blake</a></strong> <small class="value">26 films</small> <span class="content-metadata"> <a class="has-icon icon-16 icon-like" href="/undyingcheese/list/movies-that-make-me-feel-nice/likes/">41</a> <a class="has-icon icon-16 icon-edit show-for-owner" data-owner="undyingcheese" href="/undyingcheese/list/movies-that-make-me-feel-nice/edit/" rel="nofollow">Edit</a> </span> </p> </div> <div class="body-text -prose"> <p>Light, easy-to-watch movies that make me happy</p> </div> </div></section>
# </section>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# </body>

# %%
[genre_links[i].string for i in range(len(genre_links))]
# Out:
# ['mystery', 'fantasy', 'romance', 'comedy']
